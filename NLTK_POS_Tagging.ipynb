# %%
import nltk
from nltk.corpus import *

# %%
s = ['time','flies','like','an','arrow']

# %%
nltk.pos_tag(s)
# Out:
# [('time', 'NN'),
#  ('flies', 'NNS'),
#  ('like', 'IN'),
#  ('an', 'DT'),
#  ('arrow', 'NN')]

# %%
nltk.pos_tag(s, tagset = 'universal')
# Out:
# [('time', 'NOUN'),
#  ('flies', 'NOUN'),
#  ('like', 'ADP'),
#  ('an', 'DET'),
#  ('arrow', 'NOUN')]

# %%
nltk.help.upenn_tagset() #45개의 tag에 대해 설명해주는 helper
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")

# %%
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')

# %%
tagged_token
# Out:
# ('fly', 'NN')

# %%
b = brown.words()

# %%
b[:30]
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of',
#  "Atlanta's",
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that',
#  'any',
#  'irregularities',
#  'took',
#  'place',
#  '.',
#  'The',
#  'jury',
#  'further',
#  'said',
#  'in']

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
b_tagged = brown.tagged_words()

# %%
b_tagged[:30]
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('The', 'AT'),
#  ('jury', 'NN'),
#  ('further', 'RBR'),
#  ('said', 'VBD'),
#  ('in', 'IN')]

# %%
uni = nltk.corpus.brown.tagged_words(tagset='universal')

# %%
uni[:30]
# Out:
# [('The', 'DET'),
#  ('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP'),
#  ("Atlanta's", 'NOUN'),
#  ('recent', 'ADJ'),
#  ('primary', 'NOUN'),
#  ('election', 'NOUN'),
#  ('produced', 'VERB'),
#  ('``', '.'),
#  ('no', 'DET'),
#  ('evidence', 'NOUN'),
#  ("''", '.'),
#  ('that', 'ADP'),
#  ('any', 'DET'),
#  ('irregularities', 'NOUN'),
#  ('took', 'VERB'),
#  ('place', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('jury', 'NOUN'),
#  ('further', 'ADV'),
#  ('said', 'VERB'),
#  ('in', 'ADP')]

# %%
print(nltk.corpus.nps_chat.tagged_words())
# Out:
# [('now', 'RB'), ('im', 'PRP'), ('left', 'VBD'), ...]

# %%
nltk.corpus.conll2000.tagged_words()
# Out:
# [('Confidence', 'NN'), ('in', 'IN'), ('the', 'DT'), ...]

# %%
nltk.corpus.treebank.tagged_words()
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
#브라운 뉴스 카테고리에서 가장 빈번하게 출현하는 품사 리스트하기
brown_news_tagged = brown.tagged_words(categories='news',tagset='universal')

# %%
tag_fd = nltk.FreqDist(tag for (word,tag) in brown_news_tagged)

# %%
tag_fd.most_common()
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
tag_fd.plot(cumulative=True)

# %%
#명사 앞에 가장 자주 출현하는 단어 찾기
word_tag_pairs = nltk.bigrams(brown_news_tagged)

# %%
noun_preceders = [a[1] for (a,b) in word_tag_pairs if b[1] == 'NOUN']

# %%
fdist = nltk.FreqDist(noun_preceders)

# %%
[tag for (tag, _) in fdist.most_common()]
# Out:
# ['NOUN',
#  'DET',
#  'ADJ',
#  'ADP',
#  '.',
#  'VERB',
#  'CONJ',
#  'NUM',
#  'ADV',
#  'PRT',
#  'PRON',
#  'X']

# %%
#뉴스 카테고리에서 가장 빈번한 동사군들 찾기
wsj = nltk.corpus.treebank.tagged_words(tagset = 'universal')

# %%
word_tag_fd = nltk.FreqDist(wsj)

# %%
[wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# ['is',
#  'said',
#  'was',
#  'are',
#  'be',
#  'has',
#  'have',
#  'will',
#  'says',
#  'would',
#  'were',
#  'had',
#  'been',
#  'could',
#  "'s",
#  'can',
#  'do',
#  'say',
#  'make',
#  'may',
#  'did',
#  'rose',
#  'made',
#  'does',
#  'expected',
#  'buy',
#  'take',
#  'get',
#  'might',
#  'sell',
#  'added',
#  'sold',
#  'help',
#  'including',
#  'should',
#  'reported',
#  'according',
#  'pay',
#  'compared',
#  'being',
#  'fell',
#  'began',
#  'based',
#  'used',
#  'closed',
#  "'re",
#  'want',
#  'see',
#  'took',
#  'yield',
#  'offered',
#  'set',
#  'priced',
#  'approved',
#  'come',
#  'noted',
#  'cut',
#  'ended',
#  'found',
#  'increased',
#  'become',
#  'think',
#  'named',
#  'go',
#  'trying',
#  'proposed',
#  'received',
#  'growing',
#  'declined',
#  'held',
#  'give',
#  'came',
#  'use',
#  'put',
#  'making',
#  'continue',
#  'raise',
#  'estimated',
#  'called',
#  'paid',
#  'designed',
#  'going',
#  'expects',
#  'seeking',
# ...

# %%
cfd1 = nltk.ConditionalFreqDist(wsj)

# %%
cfd1['yield'].most_common()
# Out:
# [('VERB', 28), ('NOUN', 20)]

# %%
cfd1['cut'].most_common()
# Out:
# [('VERB', 25), ('NOUN', 3)]

# %%
tmp = cfd1.conditions()

# %%
# VBD(과거형) and VBN(과거분사형) 태그를 동시에 가지는 단어를 찾고, 그 주변 텍스트 살펴 보기
[w for w in cfd1.conditions() if '' in cfd1[w]]
# Out:
# []

# %%
#tagset 중 'NN'으로 시작하는 태그와 관련 단어들 리스트하기 (brown tagset)
# 요기 부분만 안된다,,,
def findtags(tag_prefix, tagged_text):
    cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text
                                  if tag.startswith(tag_prefix))
    return dict((tag, cfd[tag].most_common(5)) for tag in cfd.conditions())

# %%
tagged_wd = nltk.corpus.brown.tagged_words(categories='news')

# %%
tagdict = findtags('NN', tagged_wd)

# %%
for tag in sorted(tagdict):
    print(tag, tagdict[tag])
# Out:
# NN [('year', 137), ('time', 97), ('state', 88), ('week', 85), ('man', 72)]
# NN$ [("year's", 13), ("world's", 8), ("state's", 7), ("nation's", 6), ("city's", 6)]
# NN$-HL [("Golf's", 1), ("Navy's", 1)]
# NN$-TL [("President's", 11), ("Administration's", 3), ("Army's", 3), ("League's", 3), ("University's", 3)]
# NN-HL [('sp.', 2), ('problem', 2), ('Question', 2), ('cut', 2), ('party', 2)]
# NN-NC [('ova', 1), ('eva', 1), ('aya', 1)]
# NN-TL [('President', 88), ('House', 68), ('State', 59), ('University', 42), ('City', 41)]
# NN-TL-HL [('Fort', 2), ('Mayor', 1), ('Commissioner', 1), ('City', 1), ('Oak', 1)]
# NNS [('years', 101), ('members', 69), ('people', 52), ('sales', 51), ('men', 46)]
# NNS$ [("children's", 7), ("women's", 5), ("men's", 3), ("janitors'", 3), ("taxpayers'", 2)]
# NNS$-HL [("Dealers'", 1), ("Idols'", 1)]
# NNS$-TL [("Women's", 4), ("States'", 3), ("Giants'", 2), ("Princes'", 1), ("Bombers'", 1)]
# ...

# %%
# 단어로 검색하는 것보다 POS 태그로 검색하는 것이 나은 경우: often 단어의 사용법에 대해서 연구:
brown_learned_text = brown.words(categories = 'learned')

# %%
sorted(set(b for (a,b) in nltk.bigrams(brown_learned_text) if a == 'often'))
# Out:
# [',',
#  '.',
#  'accomplished',
#  'analytically',
#  'appear',
#  'apt',
#  'associated',
#  'assuming',
#  'became',
#  'become',
#  'been',
#  'began',
#  'call',
#  'called',
#  'carefully',
#  'chose',
#  'classified',
#  'colorful',
#  'composed',
#  'contain',
#  'differed',
#  'difficult',
#  'encountered',
#  'enough',
#  'equate',
#  'extremely',
#  'found',
#  'happens',
#  'have',
#  'ignored',
#  'in',
#  'involved',
#  'more',
#  'needed',
#  'nightly',
#  'observed',
#  'of',
#  'on',
#  'out',
#  'quite',
#  'represent',
#  'responsible',
#  'revamped',
#  'seclude',
#  'set',
#  'shortened',
#  'sing',
#  'sounded',
#  'stated',
#  'still',
#  'sung',
#  'supported',
#  'than',
#  'to',
#  'when',
#  'work']

# %%
brown_lrnd_tagged = brown.tagged_words(categories='learned', tagset = 'universal')

# %%
tags = [b[1] for (a,b) in nltk.bigrams(brown_lrnd_tagged) if a[0] == 'often']

# %%
fd = nltk.FreqDist(tags)

# %%
fd.tabulate()
# Out:
# VERB  ADV  ADP  ADJ    .  PRT
#   37    8    7    6    4    2

# %%
#단어로 검색하는 것보다 POS 태그로 검색하는 것이 나은 경우: "<Verb> to <Verb>" 구문 형태 모두 찾아 내기
#from nltk.corpus import brown
#import nltk
def process(sentence):
    for (w1,t1),(w2,t2),(w3,t3) in nltk.trigrams(sentence):
        if (t1.startswith('V') and t2 == 'TO' and t3.startswith('V')):
            print(w1,w2,w3)

# %%
for tagged_sent in brown.tagged_sents():
    process(tagged_sent)
# Out:
# combined to achieve
# continue to place
# serve to protect
# wanted to wait
# allowed to place
# expected to become
# expected to approve
# expected to make
# intends to make
# seek to set
# like to see
# designed to provide
# get to hear
# expects to tell
# expected to give
# prefer to pay
# required to obtain
# permitted to teach
# designed to reduce
# Asked to elaborate
# got to go
# raised to pay
# scheduled to go
# cut to meet
# needed to meet
# hastened to add
# found to prevent
# continue to insist
# compelled to make
# made to remove
# revamped to give
# want to risk
# appear to spark
# fails to consider
# plans to call
# going to examine
# plans to name
# come to pass
# voted to accept
# happens to hold
# authorized to adopt
# hesitated to prosecute
# try to make
# decided to spend
# taken to preserve
# left to preserve
# stand to bring
# decided to seek
# trying to induce
# proposing to make
# decided to run
# directed to investigate
# expected to pass
# expected to make
# ...

# %%
#Default Dictionary
#import nltk
pos = {'colorless':'ADJ', 'ideas':'N', 'sleep':'V','furiously':'ADV'}

# %%
pos['colorless']
# Out:
# 'ADJ'

# %%
pos['sleep']
# Out:
# 'V'

# %%
pos['blog'] #에러를 피하기 위해, 처음 보는 단어들을 전체적으로 어떻게 처리하는가?에 대해서 default dict를 사용
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-f3038bdda7fc> in <module>
# ----> 1 pos['blog']
#
# KeyError: 'blog'

# %%
from collections import defaultdict

# %%
pos = defaultdict(lambda:'NOUN')

# %%
pos['blog']
# Out:
# 'NOUN'

# %%
pos['colorless'] = 'ADJ'

# %%
pos['colorless']
# Out:
# 'ADJ'

# %%
pos['blog']
# Out:
# 'NOUN'

# %%
pos['furiously'] = 'ADV'

# %%
pos
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'blog': 'NOUN',
#              'ideas': 'NOUN',
#              'colorless': 'ADJ',
#              'furiously': 'ADV'})

# %%
#품사 갯수 세기
counts = defaultdict(int) #int가 들어갔을 때, 해당하지 않는 것은 0으로 정의

# %%
counts
# Out:
# defaultdict(int, {})

# %%
#품사 개수 세기 / 1 (using defaultdict)
for (word,tag) in brown.tagged_words(categories = 'news',tagset = 'universal'):
    counts[tag] += 1

# %%
#품사 개수 세기 / 2 (using Sorting)
counts['NOUN']
# Out:
# 30654

# %%
sorted(counts) # 알파벳 순으로 정렬
# Out:
# ['.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X']

# %%
from operator import itemgetter #sorting할 때 반드시 필요한 함수

# %%
sorted(counts.items(), key=itemgetter(1), reverse=True) #count가 많은 순서대로 sort
#items는 tuple list 형태로 바꿔줄 때 많이 사용
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
[t for t,c in sorted(counts.items(), key=itemgetter(1), reverse=True)]
# Out:
# ['X',
#  'NUM',
#  'PRT',
#  'PRON',
#  'CONJ',
#  'ADV',
#  'ADJ',
#  'DET',
#  '.',
#  'ADP',
#  'VERB',
#  'NOUN']

# %%
#complex keys and values
pos = defaultdict(lambda : defaultdict(int))

# %%
brown_news_tagged = brown.tagged_words(categories='news',tagset = 'universal')

# %%
for ((w1,t1), (w2,t2)) in nltk.bigrams(brown_news_tagged):
    pos[(t1,w2)][t2] += 1

# %%
pos[('DET','right')]
# Out:
# defaultdict(int, {'NOUN': 5, 'ADJ': 11})

# %%
#Index words according to their last two letters
last_letters = defaultdict(list)

# %%
words = nltk.corpus.words.words('en')

# %%
for word in words:
    key = word[-2:]
    last_letters[key].append(word)

# %%
last_letters['ly']
# Out:
# ['abactinally',
#  'abandonedly',
#  'abasedly',
#  'abashedly',
#  'abashlessly',
#  'abbreviately',
#  'abdominally',
#  'abhorrently',
#  'abidingly',
#  'abiogenetically',
#  'abiologically',
#  'abjectly',
#  'ableptically',
#  'ably',
#  'abnormally',
#  'abominably',
#  'aborally',
#  'aboriginally',
#  'abortively',
#  'aboundingly',
#  'abridgedly',
#  'abruptedly',
#  'abruptly',
#  'abscondedly',
#  'absently',
#  'absentmindedly',
#  'absolutely',
#  'absolutistically',
#  'absorbedly',
#  'absorbingly',
#  'absorptively',
#  'abstemiously',
#  'abstinently',
#  'abstractedly',
#  'abstractively',
#  'abstractly',
#  'abstrusely',
#  'absurdly',
#  'abundantly',
#  'abusedly',
#  'abusefully',
#  'abusively',
#  'abysmally',
#  'academically',
#  'acceleratedly',
#  'accentually',
#  'acceptably',
#  'acceptedly',
#  'accessarily',
#  'accessibly',
#  'accessively',
#  'accessorily',
#  'accidentally',
#  'accidently',
#  'accommodately',
#  'accommodatingly',
# ...

# %%
last_letters['zy']
# Out:
# ['blazy',
#  'bleezy',
#  'blowzy',
#  'boozy',
#  'breezy',
#  'bronzy',
#  'buzzy',
#  'Chazy',
#  'cozy',
#  'crazy',
#  'dazy',
#  'dizzy',
#  'dozy',
#  'enfrenzy',
#  'fezzy',
#  'fizzy',
#  'floozy',
#  'fozy',
#  'franzy',
#  'frenzy',
#  'friezy',
#  'frizzy',
#  'frowzy',
#  'furzy',
#  'fuzzy',
#  'gauzy',
#  'gazy',
#  'glazy',
#  'groszy',
#  'hazy',
#  'heezy',
#  'Izzy',
#  'jazzy',
#  'Jozy',
#  'lawzy',
#  'lazy',
#  'mazy',
#  'mizzy',
#  'muzzy',
#  'nizy',
#  'oozy',
#  'quartzy',
#  'quizzy',
#  'refrenzy',
#  'ritzy',
#  'Shortzy',
#  'sizy',
#  'sleazy',
#  'sneezy',
#  'snoozy',
#  'squeezy',
#  'Suzy',
#  'tanzy',
#  'tizzy',
#  'topazy',
#  'trotcozy',
#  'twazzy',
#  'unbreezy',
#  'unfrizzy',
#  'wheezy',
#  'woozy',
#  'wuzzy',
#  'yezzy']

# %%
brown
# Out:
# <CategorizedTaggedCorpusReader in '/Users/jianny/nltk_data/corpora/brown'>

# %%
brown.words()
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of']

# %%
brown_tagged = brown.tagged_words(tagset='universal') #tuple list로 바꿔줌
brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')

# %%
cfd = nltk.ConditionalFreqDist(brown_tagged)

# %%
cfd['time']
# Out:
# FreqDist({'NOUN': 1555, 'VERB': 1})

# %%
cfd['flies']
# Out:
# FreqDist({'NOUN': 7, 'VERB': 4})

# %%
#Default Tagger
tags = [tag for (word,tag) in brown.tagged_words(categories='news',tagset='universal')]

# %%
y = nltk.FreqDist(tags)

# %%
y
# Out:
# FreqDist({'NOUN': 30654, 'VERB': 14399, 'ADP': 12355, '.': 11928, 'DET': 11389, 'ADJ': 6706, 'ADV': 3349, 'CONJ': 2717, 'PRON': 2535, 'PRT': 2264, ...})

# %%
raw = 'I do not like green eggs and ham, I do not like them Sam I am!'

# %%
tokens = nltk.word_tokenize(raw)

# %%
default_tagger = nltk.DefaultTagger('NN')

# %%
default_tagger.tag(tokens)
# Out:
# [('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('green', 'NN'),
#  ('eggs', 'NN'),
#  ('and', 'NN'),
#  ('ham', 'NN'),
#  (',', 'NN'),
#  ('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('them', 'NN'),
#  ('Sam', 'NN'),
#  ('I', 'NN'),
#  ('am', 'NN'),
#  ('!', 'NN')]

# %%
#The regular Expression Tagger
patterns = [
    (r'.*ing$','VBG'),
    (r'.*ed$','VBD'),
    (r'.*es$','VBZ'),
    (r'.*ould$','MD'),
    (r'.*\'s$','NN$'),
    (r'.*s$','NNS'),
    (r'.*^-?[0-9]+(.[0-9]+)?$','CD'),
    (r'.*','NN'),
]

# %%
regexp_tagger = nltk.RegexpTagger(patterns)

# %%
regexp_tagger.tag(brown_sents[3])
# Out:
# [('``', 'NN'),
#  ('Only', 'NN'),
#  ('a', 'NN'),
#  ('relative', 'NN'),
#  ('handful', 'NN'),
#  ('of', 'NN'),
#  ('such', 'NN'),
#  ('reports', 'NNS'),
#  ('was', 'NNS'),
#  ('received', 'VBD'),
#  ("''", 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('jury', 'NN'),
#  ('said', 'NN'),
#  (',', 'NN'),
#  ('``', 'NN'),
#  ('considering', 'VBG'),
#  ('the', 'NN'),
#  ('widespread', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('election', 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('number', 'NN'),
#  ('of', 'NN'),
#  ('voters', 'NNS'),
#  ('and', 'NN'),
#  ('the', 'NN'),
#  ('size', 'NN'),
#  ('of', 'NN'),
#  ('this', 'NNS'),
#  ('city', 'NN'),
#  ("''", 'NN'),
#  ('.', 'NN')]

# %%
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.20326391789486245

# %%
#The NLTK UnigramTagger (The Lookup Tagger)
fd = nltk.FreqDist(brown.words(categories='news'))
cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))

# %%
most_freq_words = fd.most_common()

# %%
likely_tags = dict((word,cfd[word].max()) for (word, _) in most_freq_words)

# %%
baseline_tagger = nltk.UnigramTagger(model=likely_tags)

# %%
baseline_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9349006503968017

# %%
#Unigram Tagging:training()
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)

# %%
unigram_tagger.tag(['time','flies','like','an','arrow','.'])
# Out:
# [('time', 'NN'),
#  ('flies', 'VBZ'),
#  ('like', 'CS'),
#  ('an', 'AT'),
#  ('arrow', None),
#  ('.', '.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9349006503968017

# %%
#Separating the Training and Testing Data
size = int(len(brown_tagged_sents)*0.9)

# %%
train_sents = brown_tagged_sents[:size]

# %%
test_sents = brown_tagged_sents[size:]

# %%
size
# Out:
# 4160

# %%
unigram_tagger = nltk.UnigramTagger(train_sents)

# %%
unigram_tagger.evaluate(test_sents)
# Out:
# 0.8121200039868434

# %%
# Bigram Tagger and its Problem...
bigram_tagger = nltk.BigramTagger(train_sents)

# %%
bigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'CS'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
unseen_sent = brown_sents[4203]

# %%
bigram_tagger.tag(unseen_sent)
# Out:
# [('The', 'AT'),
#  ('population', 'NN'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('Congo', 'NP'),
#  ('is', 'BEZ'),
#  ('13.5', None),
#  ('million', None),
#  (',', None),
#  ('divided', None),
#  ('into', None),
#  ('at', None),
#  ('least', None),
#  ('seven', None),
#  ('major', None),
#  ('``', None),
#  ('culture', None),
#  ('clusters', None),
#  ("''", None),
#  ('and', None),
#  ('innumerable', None),
#  ('tribes', None),
#  ('speaking', None),
#  ('400', None),
#  ('separate', None),
#  ('dialects', None),
#  ('.', None)]

# %%
bigram_tagger.evaluate(test_sents)
# Out:
# 0.10206319146815508

# %%
#Combining Taggers
t0 = nltk.DefaultTagger('NN')

# %%
t1 = nltk.UnigramTagger(train_sents, backoff=t0)

# %%
t2 = nltk.BigramTagger(train_sents, backoff=t1)

# %%
t2.evaluate(test_sents)
# Out:
# 0.8452108043456593
